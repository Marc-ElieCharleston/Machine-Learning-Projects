# %%
import gym
import matplotlib.pyplot as plt
import time

# %%
#from gym.utils import play
#play.play(env,zoom = 3, keys_to_action={"NOOP" : 0, "FIRE" : 1, "RIGTH" : 2, "LEFT" : 3})

# %%
# gym.openai.com
env_name = "ALE/Breakout-v5"

# %%
env = gym.make(env_name, render_mode = 'human')
# Out:
# C:\Users\pc\anaconda3\envs\my_rl_env\lib\site-packages\gym\utils\passive_env_checker.py:98: UserWarning: WARN: We recommend you to use a symmetric and normalized Box action space (range=[-1, 1]) https://stable-baselines3.readthedocs.io/en/master/guide/rl_tips.html
#   "We recommend you to use a symmetric and normalized Box action space (range=[-1, 1]) "

# %%
env.reset()
for step in range(200):
    
    random_action = env.action_space.sample()
    
    obesrvation, reward, done, info = env.step(random_action)
    print("reward : "+ str(reward))
    print("Done : " + str(done))
    print("Info : "+str(info))
    print("---------------------")
    
    if done:
        break
    
    
    time.sleep(0.1)
env.close()
# Out:
# reward : 0.0
# Done : False
# Info : {'lives': 5, 'episode_frame_number': 4, 'frame_number': 4}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 5, 'episode_frame_number': 8, 'frame_number': 8}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 5, 'episode_frame_number': 12, 'frame_number': 12}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 5, 'episode_frame_number': 16, 'frame_number': 16}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 5, 'episode_frame_number': 20, 'frame_number': 20}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 5, 'episode_frame_number': 24, 'frame_number': 24}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 5, 'episode_frame_number': 28, 'frame_number': 28}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 5, 'episode_frame_number': 32, 'frame_number': 32}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 5, 'episode_frame_number': 36, 'frame_number': 36}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 5, 'episode_frame_number': 40, 'frame_number': 40}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 5, 'episode_frame_number': 44, 'frame_number': 44}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 5, 'episode_frame_number': 48, 'frame_number': 48}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 5, 'episode_frame_number': 52, 'frame_number': 52}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 5, 'episode_frame_number': 56, 'frame_number': 56}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 5, 'episode_frame_number': 60, 'frame_number': 60}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 5, 'episode_frame_number': 64, 'frame_number': 64}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 5, 'episode_frame_number': 68, 'frame_number': 68}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 5, 'episode_frame_number': 72, 'frame_number': 72}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 5, 'episode_frame_number': 76, 'frame_number': 76}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 5, 'episode_frame_number': 80, 'frame_number': 80}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 5, 'episode_frame_number': 84, 'frame_number': 84}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 5, 'episode_frame_number': 88, 'frame_number': 88}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 5, 'episode_frame_number': 92, 'frame_number': 92}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 5, 'episode_frame_number': 96, 'frame_number': 96}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 5, 'episode_frame_number': 100, 'frame_number': 100}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 5, 'episode_frame_number': 104, 'frame_number': 104}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 5, 'episode_frame_number': 108, 'frame_number': 108}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 5, 'episode_frame_number': 112, 'frame_number': 112}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 5, 'episode_frame_number': 116, 'frame_number': 116}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 5, 'episode_frame_number': 120, 'frame_number': 120}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 5, 'episode_frame_number': 124, 'frame_number': 124}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 5, 'episode_frame_number': 128, 'frame_number': 128}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 4, 'episode_frame_number': 132, 'frame_number': 132}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 4, 'episode_frame_number': 136, 'frame_number': 136}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 4, 'episode_frame_number': 140, 'frame_number': 140}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 4, 'episode_frame_number': 144, 'frame_number': 144}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 4, 'episode_frame_number': 148, 'frame_number': 148}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 4, 'episode_frame_number': 152, 'frame_number': 152}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 4, 'episode_frame_number': 156, 'frame_number': 156}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 4, 'episode_frame_number': 160, 'frame_number': 160}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 4, 'episode_frame_number': 164, 'frame_number': 164}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 4, 'episode_frame_number': 168, 'frame_number': 168}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 4, 'episode_frame_number': 172, 'frame_number': 172}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 4, 'episode_frame_number': 176, 'frame_number': 176}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 4, 'episode_frame_number': 180, 'frame_number': 180}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 4, 'episode_frame_number': 184, 'frame_number': 184}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 4, 'episode_frame_number': 188, 'frame_number': 188}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 4, 'episode_frame_number': 192, 'frame_number': 192}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 4, 'episode_frame_number': 196, 'frame_number': 196}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 4, 'episode_frame_number': 200, 'frame_number': 200}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 4, 'episode_frame_number': 204, 'frame_number': 204}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 4, 'episode_frame_number': 208, 'frame_number': 208}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 4, 'episode_frame_number': 212, 'frame_number': 212}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 4, 'episode_frame_number': 216, 'frame_number': 216}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 4, 'episode_frame_number': 220, 'frame_number': 220}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 4, 'episode_frame_number': 224, 'frame_number': 224}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 4, 'episode_frame_number': 228, 'frame_number': 228}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 4, 'episode_frame_number': 232, 'frame_number': 232}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 4, 'episode_frame_number': 236, 'frame_number': 236}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 4, 'episode_frame_number': 240, 'frame_number': 240}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 244, 'frame_number': 244}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 248, 'frame_number': 248}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 252, 'frame_number': 252}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 256, 'frame_number': 256}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 260, 'frame_number': 260}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 264, 'frame_number': 264}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 268, 'frame_number': 268}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 272, 'frame_number': 272}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 276, 'frame_number': 276}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 280, 'frame_number': 280}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 284, 'frame_number': 284}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 288, 'frame_number': 288}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 292, 'frame_number': 292}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 296, 'frame_number': 296}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 300, 'frame_number': 300}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 304, 'frame_number': 304}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 308, 'frame_number': 308}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 312, 'frame_number': 312}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 316, 'frame_number': 316}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 320, 'frame_number': 320}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 324, 'frame_number': 324}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 328, 'frame_number': 328}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 332, 'frame_number': 332}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 336, 'frame_number': 336}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 340, 'frame_number': 340}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 344, 'frame_number': 344}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 348, 'frame_number': 348}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 352, 'frame_number': 352}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 356, 'frame_number': 356}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 360, 'frame_number': 360}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 364, 'frame_number': 364}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 368, 'frame_number': 368}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 372, 'frame_number': 372}
# ---------------------
# reward : 1.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 376, 'frame_number': 376}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 380, 'frame_number': 380}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 384, 'frame_number': 384}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 388, 'frame_number': 388}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 392, 'frame_number': 392}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 396, 'frame_number': 396}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 400, 'frame_number': 400}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 404, 'frame_number': 404}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 408, 'frame_number': 408}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 412, 'frame_number': 412}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 416, 'frame_number': 416}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 420, 'frame_number': 420}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 424, 'frame_number': 424}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 428, 'frame_number': 428}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 432, 'frame_number': 432}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 436, 'frame_number': 436}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 440, 'frame_number': 440}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 444, 'frame_number': 444}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 448, 'frame_number': 448}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 452, 'frame_number': 452}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 3, 'episode_frame_number': 456, 'frame_number': 456}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 2, 'episode_frame_number': 460, 'frame_number': 460}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 2, 'episode_frame_number': 464, 'frame_number': 464}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 2, 'episode_frame_number': 468, 'frame_number': 468}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 2, 'episode_frame_number': 472, 'frame_number': 472}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 2, 'episode_frame_number': 476, 'frame_number': 476}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 2, 'episode_frame_number': 480, 'frame_number': 480}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 2, 'episode_frame_number': 484, 'frame_number': 484}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 2, 'episode_frame_number': 488, 'frame_number': 488}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 2, 'episode_frame_number': 492, 'frame_number': 492}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 2, 'episode_frame_number': 496, 'frame_number': 496}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 2, 'episode_frame_number': 500, 'frame_number': 500}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 2, 'episode_frame_number': 504, 'frame_number': 504}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 2, 'episode_frame_number': 508, 'frame_number': 508}
# ---------------------
# reward : 0.0
# Done : False
# Info : {'lives': 2, 'episode_frame_number': 512, 'frame_number': 512}
# ---------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13532\3002361240.py in <module>
#      11
#      12
# ---> 13     time.sleep(0.1)
#      14 env.close()
#
# KeyboardInterrupt:

# %%
env.close()

# %% [markdown]
# import gym
# from IPython import display
# import matplotlib
# import matplotlib.pyplot as plt
# %matplotlib inline
#
#
#
# env.reset()
# img = plt.imshow(env.render(mode='rgb_array')) # only call this once
# for _ in range(100):
#     img.set_data(env.render(mode='rgb_array')) # just update the data
#     display.display(plt.gcf())
#     display.clear_output(wait=True)
#     random_action = env.action_space.sample()
#     observation, reward, done, info = env.step(random_action)
#
#
# env.close()

# %% [markdown]
# import gym
# env = gym.make("CartPole-v1")
# env.action_space.seed(42)
#
# observation, info = env.reset(seed=42, return_info=True)
#
# for _ in range(1000):
#     observation, reward, done, info = env.step(env.action_space.sample())
#     env.render()
#
#     if done:
#         observation, info = env.reset(return_info=True)
#
# env.close()
