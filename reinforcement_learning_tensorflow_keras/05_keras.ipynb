# %%
import pandas as pd
import numpy as np

import seaborn as sns

# %%
df = pd.read_csv('C:/Users/pc/Desktop/Ma formation Data - udemy - youtube/Projets/4 Udemy reinforcement learning 2/DATA/fake_reg.csv')

# %%
df.head()
# Out:
#         price     feature1     feature2
# 0  461.527929   999.787558   999.766096
# 1  548.130011   998.861615  1001.042403
# 2  410.297162  1000.070267   998.844015
# 3  540.382220   999.952251  1000.440940
# 4  546.024553  1000.446011  1000.338531

# %%
sns.pairplot(df)

# %%
from sklearn.model_selection import train_test_split

# %%
X = df[['feature1','feature2']].values
y = df['price'].values
V = df.copy()
w = V.pop('price')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 1)
V_train, V_test, w_train, w_test = train_test_split(V, w, test_size=0.3, random_state = 1)

# %%
X_train
# Out:
# array([[1001.65864075, 1000.22533837],
#        [ 999.43095565, 1001.4468994 ],
#        [1000.60761966,  999.03363032],
#        ...,
#        [ 998.57023261, 1000.0490836 ],
#        [ 999.64595458, 1001.41226397],
#        [ 998.51053268,  999.03076963]])

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_train.shape
# Out:
# (700, 2)

# %%
X_test = scaler.transform(X_test)
X_test
# Out:
# array([[ 0.36778598,  0.54532143],
#        [ 0.47817176,  0.58143397],
#        [ 0.58907136,  0.4770078 ],
#        [ 0.64137776,  0.53071311],
#        [ 0.43191648,  0.85382289],
#        [ 0.27772922,  0.29831013],
#        [ 0.46313125, -0.00707422],
#        [ 0.3254073 ,  0.37052521],
#        [ 0.48884569,  0.94089699],
#        [ 0.69000272,  0.4453593 ],
#        [ 0.60466697,  0.43837464],
#        [ 0.49712881,  0.53842956],
#        [ 0.57346822,  0.4843206 ],
#        [ 0.21154135,  0.39134055],
#        [ 0.5035187 ,  0.61205685],
#        [ 0.32324928,  0.59785815],
#        [ 0.58243263,  0.63047285],
#        [ 0.52320719,  0.60550026],
#        [ 0.55460158,  0.46809071],
#        [ 0.41652088,  0.56198635],
#        [ 0.68330823,  0.36832961],
#        [ 0.75066074,  0.60612483],
#        [ 0.48163664,  0.41877491],
#        [ 0.40443028,  0.72256797],
#        [ 0.42674843,  0.41422198],
#        [ 0.51982619,  0.55546013],
#        [ 0.27252699,  0.41613865],
# ...

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
"""model = Sequential([Dense(4,activation = 'relu'),
                    Dense(2, activation = 'relu')
                    Dense(1)])"""
# Out:
# "model = Sequential([Dense(4,activation = 'relu'),\n                    Dense(2, activation = 'relu')\n                    Dense(1)])"

# %%
model = Sequential()
model.add(Dense(4,activation = 'relu'))
model.add(Dense(4,activation = 'relu'))
model.add(Dense(4,activation = 'relu'))

model.add(Dense(1))

model.compile(optimizer='rmsprop', loss='mse')

# %%
model.fit(x=X_train,
          y=y_train,
         epochs = 250)
# Out:
# Epoch 1/250
# 22/22 [==============================] - 0s 904us/step - loss: 255667.2969
# Epoch 2/250
# 22/22 [==============================] - 0s 904us/step - loss: 255634.7500
# Epoch 3/250
# 22/22 [==============================] - 0s 857us/step - loss: 255600.5469
# Epoch 4/250
# 22/22 [==============================] - 0s 857us/step - loss: 255561.5469
# Epoch 5/250
# 22/22 [==============================] - 0s 857us/step - loss: 255519.9375
# Epoch 6/250
# 22/22 [==============================] - 0s 857us/step - loss: 255475.0156
# Epoch 7/250
# 22/22 [==============================] - 0s 857us/step - loss: 255426.9219
# Epoch 8/250
# 22/22 [==============================] - 0s 857us/step - loss: 255375.0625
# Epoch 9/250
# 22/22 [==============================] - 0s 857us/step - loss: 255318.1719
# Epoch 10/250
# 22/22 [==============================] - 0s 857us/step - loss: 255252.7812
# Epoch 11/250
# ...

# %%
loss_df = pd.DataFrame(model.history.history)

# %%
loss_df.plot()
# Out:
# <AxesSubplot:>

# %%
model.evaluate(X_test, y_test, verbose=0)
# Out:
# 27.96394920349121

# %%
model.evaluate(X_train, y_train, verbose = 0)
# Out:
# 22.59751319885254

# %%
test_predictions = model.predict(X_test)
# Out:
# 10/10 [==============================] - 0s 778us/step

# %%
test_predictions = pd.Series(test_predictions.reshape(300,))

# %%
test_predictions
# Out:
# 0    481.966583
# 1    527.020081
# 2    502.261810
# 3    541.820862
# 4    651.223877
# dtype: float32

# %%
pred_df = pd.DataFrame(y_test, columns = ['Test True Y'])

# %%
pred_df = pd.concat([pred_df, test_predictions], axis =1)

# %%
pred_df.columns = ['Test True Y', 'Model Predictions']

# %%
pred_df
# Out:
#      Test True Y  Model Predictions
# 0     489.057552         481.966583
# 1     526.210746         527.020081
# 2     518.360395         502.261810
# 3     552.778935         541.820862
# 4     649.395917         651.223877
# ..           ...                ...
# 295   530.276259         534.241333
# 296   481.645813         480.564423
# 297   460.694781         466.557220
# 298   518.263124         518.116028
# 299   512.595702         511.706604
#
# [300 rows x 2 columns]

# %%
sns.scatterplot(x='Test True Y', y = 'Model Predictions', data = pred_df)
# Out:
# <AxesSubplot:xlabel='Test True Y', ylabel='Model Predictions'>

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mean_absolute_error(pred_df['Test True Y'], pred_df['Model Predictions'])
# Out:
# 4.2552091427994645

# %%
mean_squared_error(pred_df['Test True Y'], pred_df['Model Predictions'])
# Out:
# 27.963961380092698

# %%
df.describe()
# Out:
#              price     feature1     feature2
# count  1000.000000  1000.000000  1000.000000
# mean    498.673029  1000.014171   999.979847
# std      93.785431     0.974018     0.948330
# min     223.346793   997.058347   996.995651
# 25%     433.025732   999.332068   999.316106
# 50%     502.382117  1000.009915  1000.002243
# 75%     564.921588  1000.637580  1000.645380
# max     774.407854  1003.207934  1002.666308

# %%
new_gem = [[998,1000]]
new_gem = scaler.transform(new_gem)
model.predict(new_gem)
# Out:
# 1/1 [==============================] - 0s 19ms/step
# array([[419.9245]], dtype=float32)

# %%
from tensorflow.keras.models import load_model
model.save('my_gem_model.h5')
later_model = load_model('my_gem_model.h5')

# %%
later_model.predict(new_gem)
# Out:
# 1/1 [==============================] - 0s 43ms/step
# array([[419.9245]], dtype=float32)
